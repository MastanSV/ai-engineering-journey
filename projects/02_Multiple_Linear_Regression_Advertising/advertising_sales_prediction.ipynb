# %%
# =============================================================================
#          ADVERTISING BUDGET VS SALES PREDICTION
#          MULTIPLE LINEAR REGRESSION PROJECT
# =============================================================================


import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score


data = {
    'TV': [230.1, 44.5, 17.2, 151.5, 180.8, 8.7, 57.5, 120.2, 8.6, 199.8],
    'Radio': [37.8, 39.3, 45.9, 41.3, 10.8, 48.9, 32.8, 19.6, 2.1, 2.6],
    'Newspaper': [69.2, 45.1, 69.3, 58.5, 58.4, 75.0, 23.5, 11.6, 1.0, 21.2],
    'Sales': [22.1, 10.4, 9.3, 18.5, 12.9, 7.2, 11.8, 13.2, 4.8, 10.6]
}

df = pd.DataFrame(data=data)

print("=== Dataset Loaded Successfully ===")
print(f'Shape of dataset: {df.shape}')
print("\nFirst 5 rows:")
print(df.head())

print("\nBasic Statistics:")
print(df.describe())

print("\n=====Basic Statistics Summary=====")
print(df.describe().round(2))


# -------------------------- Exploratory Data Analysis --------------------------
print("\n=== Correlation Between Features and Sales ===")
print(df.corr()['Sales'].sort_values(ascending=False))

sns.pairplot(df)\

X = df[['TV', 'Radio', 'Newspaper']]
y = df['Sales']

model = LinearRegression()
model.fit(X=X, y=y)

print("\n=== Multiple Linear Regression Results ===")
print(f'Coef. for TV = {model.coef_[0]:.4f}')
print(f'Coef. for Radio = {model.coef_[1]:.4f}')
print(f'Coef. for Newspaper = {model.coef_[2]:.4f}')
print(f'Intercept = {model.intercept_:.4f}')
print(f'r**2 = {model.score(X, y)}')


# -------------------------- Model Evaluation --------------------------
print("\n === Model Evaluation ===")

y_pred = model.predict(X)
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y, y_pred)
mae = mean_absolute_error(y, y_pred)

print("\n === Model Performance ===")
print(f"R2 score = {r2:.4f} ({r2*100:.2f}%)")
print(f"Mean squared Error : {mse:.4f}")
print(f"Root Mean Squared Error : {rmse:.4f}")
print(f"Mean Absolute Error : {mae:.4f}")
# Out:
# === Dataset Loaded Successfully ===
# Shape of dataset: (10, 4)
#
# First 5 rows:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9
#
# Basic Statistics:
#               TV      Radio  Newspaper      Sales
# count   10.00000  10.000000  10.000000  10.000000
# mean   101.89000  28.110000  43.280000  12.080000
# std     84.89945  17.836071  26.850649   5.090034
# min      8.60000   2.100000   1.000000   4.800000
# 25%     24.02500  13.000000  21.775000   9.575000
# 50%     88.85000  35.300000  51.750000  11.200000
# 75%    173.47500  40.800000  66.525000  13.125000
# max    230.10000  48.900000  75.000000  22.100000
#
# =====Basic Statistics Summary=====
#            TV  Radio  Newspaper  Sales
# count   10.00  10.00      10.00  10.00
# mean   101.89  28.11      43.28  12.08
# std     84.90  17.84      26.85   5.09
# min      8.60   2.10       1.00   4.80
# 25%     24.02  13.00      21.78   9.58
# 50%     88.85  35.30      51.75  11.20
# 75%    173.48  40.80      66.53  13.12
# max    230.10  48.90      75.00  22.10
#
# === Correlation Between Features and Sales ===
# Sales        1.000000
# TV           0.776924
# Newspaper    0.365986
# Radio        0.262071
# Name: Sales, dtype: float64
#
# === Multiple Linear Regression Results ===
# Coef. for TV = 0.0633
# Coef. for Radio = 0.2374
# Coef. for Newspaper = -0.0671
# Intercept = 1.8555
# r**2 = 0.9093762082693512
#
#  === Model Evaluation ===
#
#  === Model Performance ===
# R2 score = 0.9094 (90.94%)
# Mean squared Error : 2.1131
# Root Mean Squared Error : 1.4537
# Mean Absolute Error : 1.1232
